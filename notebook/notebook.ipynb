# %%
# !pip install split-folders

# %%
# !pip install split-folders

import splitfolders

splitfolders.ratio(
    "data/raw",
    output="data/final",
    seed=42,
    ratio=(0.8, 0.2)
)
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 get_ipython().system('pip install split-folders')
#       3 import splitfolders
# ----> 5 splitfolders.ratio(
#       6     "data/raw",
#       7     output="data/final",
#       8     seed=42,
#       9     ratio=(0.8, 0.2)
#      10 )
#
# File d:\brain_tumor\venv\Lib\site-packages\splitfolders\split.py:81, in ratio(input, output, seed, ratio, group_prefix, move)
#      78 if not len(ratio) in (2, 3):
#      79     raise ValueError("`ratio` should")
# ---> 81 check_input_format(input)
#      83 if use_tqdm:
#      84     prog_bar = tqdm(desc=f"Copying files", unit=" files")
#
# File d:\brain_tumor\venv\Lib\site-packages\splitfolders\split.py:56, in check_input_format(input)
#      54     if not p_input.is_absolute():
# ...

# %%
import splitfolders

splitfolders.ratio(
    r"d:\brain_tumor\data\raw",   # ✅ absolute path
    output=r"d:\brain_tumor\data\final",
    seed=42,
    ratio=(0.8, 0.2)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import splitfolders
# ----> 3 splitfolders.ratio(
#       4     r"d:\brain_tumor\Data\raw",   # ✅ absolute path
#       5     output=r"d:\brain_tumor\Data\final",
#       6     seed=42,
#       7     ratio=(0.8, 0.2)
#       8 )
#
# File d:\brain_tumor\venv\Lib\site-packages\splitfolders\split.py:81, in ratio(input, output, seed, ratio, group_prefix, move)
#      78 if not len(ratio) in (2, 3):
#      79     raise ValueError("`ratio` should")
# ---> 81 check_input_format(input)
#      83 if use_tqdm:
#      84     prog_bar = tqdm(desc=f"Copying files", unit=" files")
#
# File d:\brain_tumor\venv\Lib\site-packages\splitfolders\split.py:56, in check_input_format(input)
#      54     if not p_input.is_absolute():
# ...

# %%
import os
os.chdir("d:/brain_tumor")

import splitfolders
splitfolders.ratio(
    "data/raw",
    output="data/final",
    seed=42,
    ratio=(0.8, 0.2)
)
