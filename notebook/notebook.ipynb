# %%
import os
print(os.getcwd())                 # shows current directory
print(os.path.exists("../data/raw"))
# Out:
# d:\brain_tumor
# False

# %%
import os
print(os.getcwd())
# Out:
# d:\brain_tumor

# %%
# !dir
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 9276-08F1
#
#  Directory of d:\brain_tumor
#
# 01/01/2026  04:50 PM    <DIR>          .
# 01/01/2026  04:36 PM    <DIR>          Data
# 01/01/2026  04:53 PM    <DIR>          notebook
# 01/01/2026  04:46 PM                92 requirements.txt
# 01/01/2026  04:45 PM    <DIR>          src
# 01/01/2026  04:48 PM    <DIR>          venv
#                1 File(s)             92 bytes
#                5 Dir(s)  62,454,009,856 bytes free

# %%
# !dir Data
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 9276-08F1
#
#  Directory of d:\brain_tumor\Data
#
# 01/01/2026  04:36 PM    <DIR>          .
# 01/01/2026  04:50 PM    <DIR>          ..
# 01/01/2026  04:36 PM    <DIR>          glioma_tumor
# 01/01/2026  04:36 PM    <DIR>          meningioma_tumor
# 01/01/2026  04:36 PM    <DIR>          normal
# 01/01/2026  04:36 PM    <DIR>          pituitary_tumor
#                0 File(s)              0 bytes
#                6 Dir(s)  62,454,009,856 bytes free

# %%
import splitfolders

splitfolders.ratio(
    "Data",              # ✅ correct input
    output="data/final", # creates new folder
    seed=42,
    ratio=(0.8, 0.2)
)

# %%
# !dir data\final\train
# !dir data\final\val
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 9276-08F1
#
#  Directory of d:\brain_tumor\data\final\train
#
# 01/01/2026  05:08 PM    <DIR>          .
# 01/01/2026  05:08 PM    <DIR>          ..
# 01/01/2026  05:08 PM    <DIR>          glioma_tumor
# 01/01/2026  05:08 PM    <DIR>          meningioma_tumor
# 01/01/2026  05:08 PM    <DIR>          normal
# 01/01/2026  05:08 PM    <DIR>          pituitary_tumor
#                0 File(s)              0 bytes
#                6 Dir(s)  62,380,818,432 bytes free
#  Volume in drive D is New Volume
#  Volume Serial Number is 9276-08F1
#
#  Directory of d:\brain_tumor\data\final\val
#
# 01/01/2026  05:08 PM    <DIR>          .
# 01/01/2026  05:08 PM    <DIR>          ..
# 01/01/2026  05:08 PM    <DIR>          glioma_tumor
# 01/01/2026  05:08 PM    <DIR>          meningioma_tumor
# 01/01/2026  05:08 PM    <DIR>          normal
# 01/01/2026  05:08 PM    <DIR>          pituitary_tumor
#                0 File(s)              0 bytes
#                6 Dir(s)  62,380,818,432 bytes free

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
print("GPUs:", gpus)

if gpus:
    print("✅ GPU is available and TensorFlow can see it")
else:
    print("❌ GPU NOT detected by TensorFlow")
# Out:
# d:\brain_tumor\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# GPUs: []
# ❌ GPU NOT detected by TensorFlow

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.20.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
